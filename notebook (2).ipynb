# %%
# Start coding here...

# %% [markdown]
# My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# include your name, in bold characters. In the line below your name, write your current or desired occupation in regular font.
# **Huajie Li**
# data analyst

# %% [markdown]
# _In italic formatting, write one or two sentences about why you are interested in data science. For example, you can start your first sentence with "I am interested in data science because ..."_
# _i am interesteed in data science because it can predict healthcare, ecommerce situations._

# %% [markdown]
# ### In H3 header styling, explain in a short sentence what your code is supposed to do in Cell 5
#
# ### not at all.

# %% [markdown]
# Your code, as described in Cell 4. It must be executed and must display an output. Try to keep the code simple (it can even be "1 + 1").

# %% [markdown]
# Using Markdown or HTML, this cell must include at least 3 of the following: horizontal rule, bulleted list, numbered list, tables, hyperlinks, images, code/syntax highlighting, blocked quotes, strikethrough.

# %%
[link to MIT Technology Review] (https://www.technologyreview.com)

![image of a hydrogen-powered plane test flight] (https://wp.technologyreview.com/wp-content/uploads/2023/01/ZeroAvia_first_flight-crop.jpeg?fit=2252,1266)
# Out:
#   Input In [1]
#     [link to MIT Technology Review] (https://www.technologyreview.com)
#           ^
# SyntaxError: invalid syntax

# %% [markdown]
# Machine Learning
# - Unsupervised Learning
# Regression
# - Classification
# - Supervised Learning
# - Clustering

# %%
user = input("Please enter your name :")
print("Hello there, {}".format(user))
# Out:
# ---------------------------------------------------------------------------
# StdinNotImplementedError                  Traceback (most recent call last)
# Input In [2], in <cell line: 1>()
# ----> 1 user = input("Please enter your name :")
#       2 print("Hello there, {}".format(user))
#
# File /usr/local/lib/python3.8/dist-packages/ipykernel/kernelbase.py:1174, in Kernel.raw_input(self, prompt)
#    1167 """Forward raw_input to frontends
#    1168
#    1169 Raises
#    1170 ------
#    1171 StdinNotImplementedError if active frontend doesn't support stdin.
#    1172 """
#    1173 if not self._allow_stdin:
# -> 1174     raise StdinNotImplementedError(
#    1175         "raw_input was called, but this frontend does not support input requests."
#    1176     )
#    1177 return self._input_request(
#    1178     str(prompt),
#    1179     self._parent_ident["shell"],
#    1180     self.get_parent("shell"),
#    1181     password=False,
#    1182 )
#
# ...

# %%
1+1
# Out:
# 2
